# %%
# Import dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import mean_absolute_error

# %%
# Load cleaned_movies dataset into a data frame.
movies_df = pd.read_csv('movies_final.csv') 
movies_df.head()
# Out:
#    Unnamed: 0                                            name rating  \
# 0           0                                     The Shining      R
# 1           1                                 The Blue Lagoon      R
# 2           2  Star Wars: Episode V - The Empire Strikes Back     PG
# 3           3                                       Airplane!     PG
# 4           4                                      Caddyshack      R
#
#        genre  year                       released  score      votes  \
# 0      Drama  1980  June 13, 1980 (United States)    8.4   927000.0
# 1  Adventure  1980   July 2, 1980 (United States)    5.8    65000.0
# 2     Action  1980  June 20, 1980 (United States)    8.7  1200000.0
# 3     Comedy  1980   July 2, 1980 (United States)    7.7   221000.0
# 4     Comedy  1980  July 25, 1980 (United States)    7.3   108000.0
#
#           director                   writer            star         country  \
# 0  Stanley Kubrick             Stephen King  Jack Nicholson  United Kingdom
# 1   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields   United States
# 2   Irvin Kershner           Leigh Brackett     Mark Hamill   United States
# 3     Jim Abrahams             Jim Abrahams     Robert Hays   United States
# 4     Harold Ramis       Brian Doyle-Murray     Chevy Chase   United States
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# Determine dtypes
movies_df.dtypes
# Out:
# Unnamed: 0      int64
# name           object
# rating         object
# genre          object
# year            int64
# released       object
# score         float64
# votes         float64
# director       object
# writer         object
# star           object
# country        object
# gross         float64
# company        object
# runtime       float64
# dtype: object

# %%
# Determine if year needs binning
release_year = movies_df['year'].value_counts()
release_year
# Out:
# 2009    200
# 2002    200
# 2014    200
# 2013    200
# 2005    200
# 2018    199
# 2006    199
# 2007    199
# 2008    199
# 2011    199
# 2012    199
# 2016    199
# 2017    199
# 2004    199
# 1994    198
# 1996    198
# 2010    197
# 2001    197
# 2003    197
# 1995    196
# 1997    196
# 2015    196
# 1991    195
# 1993    195
# 1998    194
# 2000    193
# 1999    193
# 1988    191
# 1992    189
# 1990    189
# 1989    186
# 1987    186
# 1986    182
# 2019    180
# 1985    177
# 1984    155
# 1983    127
# 1982    118
# 1981    103
# 1980     80
# 2020     13
# Name: year, dtype: int64

# %%
# Determine if genre needs binning
genres = movies_df['genre'].value_counts()
genres
# Out:
# Comedy       2182
# Action       1666
# Drama        1439
# Crime         536
# Biography     429
# Adventure     419
# Animation     331
# Horror        304
# Fantasy        42
# Mystery        20
# Thriller       12
# Family         10
# Romance         8
# Sci-Fi          8
# Western         3
# Music           1
# Sport           1
# Musical         1
# Name: genre, dtype: int64

# %%
# Bin genres with less than 5 movies into 'Other'
replace_genre = list(genres[genres < 5].index)

# Replace in DataFrame
for genre in replace_genre:
    movies_df['genre'] = movies_df['genre'].replace(genre,'Other')
    
# Check to make sure binning was successful
movies_df['genre'].value_counts()
# Out:
# Comedy       2182
# Action       1666
# Drama        1439
# Crime         536
# Biography     429
# Adventure     419
# Animation     331
# Horror        304
# Fantasy        42
# Mystery        20
# Thriller       12
# Family         10
# Romance         8
# Sci-Fi          8
# Other           6
# Name: genre, dtype: int64

# %%
# Determine number of directors
# bottom 1000 only have 1
# bottom 1500 starts at 2
# bottom 2000 starts at 3
# bottom 2500 starts at 5
directors = movies_df['director'].value_counts()
director_count = pd.DataFrame(directors)
director_count.tail(3000)
# Out:
#                   director
# Woody Allen             38
# Clint Eastwood          31
# Steven Spielberg        27
# Directors               25
# Ron Howard              24
# ...                    ...
# Daniel Myrick            1
# Tony Cinciripini         1
# Rodney Gibbons           1
# Nicole Garcia            1
# Kevin Shulman            1
#
# [2816 rows x 1 columns]

# %%
# Get movies
movies_director = movies_df['director'].value_counts() == 1
delete_directors = []
df1 = movies_df[movies_df['director'].map(movies_df['director'].value_counts()) != 1]
df1
# Out:
#       Unnamed: 0                                            name rating  \
# 0              0                                     The Shining      R
# 1              1                                 The Blue Lagoon      R
# 2              2  Star Wars: Episode V - The Empire Strikes Back     PG
# 3              3                                       Airplane!     PG
# 4              4                                      Caddyshack      R
# ...          ...                                             ...    ...
# 7399        7643                                           Tenet  PG-13
# 7400        7644                               Wonder Woman 1984  PG-13
# 7402        7646                               The Invisible Man      R
# 7403        7647                                          Onward     PG
# 7406        7650                                        Dolittle     PG
#
#           genre  year                           released  score      votes  \
# 0         Drama  1980      June 13, 1980 (United States)    8.4   927000.0
# 1     Adventure  1980       July 2, 1980 (United States)    5.8    65000.0
# 2        Action  1980      June 20, 1980 (United States)    8.7  1200000.0
# 3        Comedy  1980       July 2, 1980 (United States)    7.7   221000.0
# 4        Comedy  1980      July 25, 1980 (United States)    7.3   108000.0
# ...         ...   ...                                ...    ...        ...
# 7399     Action  2020  September 3, 2020 (United States)    7.4   387000.0
# 7400     Action  2020  December 25, 2020 (United States)    5.4   217000.0
# 7402      Drama  2020  February 28, 2020 (United States)    7.1   186000.0
# 7403  Animation  2020      March 6, 2020 (United States)    7.4   120000.0
# 7406  Adventure  2020   January 17, 2020 (United States)    5.6    53000.0
#
#                director                   writer                   star  \
# 0       Stanley Kubrick             Stephen King         Jack Nicholson
# 1        Randal Kleiser  Henry De Vere Stacpoole         Brooke Shields
# 2        Irvin Kershner           Leigh Brackett            Mark Hamill
# 3          Jim Abrahams             Jim Abrahams            Robert Hays
# 4          Harold Ramis       Brian Doyle-Murray            Chevy Chase
# ...                 ...                      ...                    ...
# 7399  Christopher Nolan        Christopher Nolan  John David Washington
# 7400      Patty Jenkins            Patty Jenkins              Gal Gadot
# 7402     Leigh Whannell           Leigh Whannell         Elisabeth Moss
# 7403        Dan Scanlon              Dan Scanlon            Tom Holland
# 7406     Stephen Gaghan           Stephen Gaghan      Robert Downey Jr.
#
#              country        gross               company  runtime
# 0     United Kingdom   46998772.0          Warner Bros.    146.0
# 1      United States   58853106.0     Columbia Pictures    104.0
# 2      United States  538375067.0             Lucasfilm    124.0
# 3      United States   83453539.0    Paramount Pictures     88.0
# 4      United States   39846344.0        Orion Pictures     98.0
# ...              ...          ...                   ...      ...
# 7399   United States  363656624.0          Warner Bros.    150.0
# 7400   United States  166534027.0   Atlas Entertainment    151.0
# 7402          Canada  143151000.0    Universal Pictures    124.0
# 7403   United States  141950608.0  Walt Disney Pictures    102.0
# 7406   United States  245487753.0    Universal Pictures    101.0
#
# [5949 rows x 15 columns]

# %%
df1['director'].value_counts()
# Out:
# Woody Allen         38
# Clint Eastwood      31
# Steven Spielberg    27
# Directors           25
# Ron Howard          24
#                     ..
# Tom Hanks            2
# David Hogan          2
# Steve Buscemi        2
# Matthew Bright       2
# Adam Robitel         2
# Name: director, Length: 1353, dtype: int64

# %%
# Determine number of starring actors/actresses
# bottom 1500 only have 1
# bottom 2000 starts at 3
# bottom 2250 starts at 4
# bottom 2500 starts at 10
stars = movies['star'].value_counts()
star_count = pd.DataFrame(stars)
star_count.tail(2250)
# Out:
#                   star
# Jonah Hill           4
# Jim Varney           4
# Taraji P. Henson     4
# Bruce Campbell       4
# Christopher Reid     4
# ...                ...
# Teri Hatcher         1
# Pamela Anderson      1
# Mike Judge           1
# Kim Bodnia           1
# Kristina Klebe       1
#
# [2250 rows x 1 columns]

# %%
# Split the data into features and target
# Create our features
X = pd.get_dummies(movies, columns=['rating', 'genre', 'year', 'director', 
                'writer', 'star', 'country', 'company']).drop('score', axis=1)


# Create our target
y = movies['score']

# %%
#
X.describe()
# Out:
#         Unnamed: 0         votes         gross      runtime  rating_Approved  \
# count  7412.000000  7.412000e+03  7.412000e+03  7412.000000      7412.000000
# mean   3878.402995  9.076357e+04  7.899355e+07   107.446438         0.000135
# std    2190.832442  1.653466e+05  1.662164e+08    18.517471         0.011615
# min       0.000000  1.050000e+02  3.090000e+02    63.000000         0.000000
# 25%    2004.750000  1.000000e+04  4.633888e+06    95.000000         0.000000
# 50%    3908.500000  3.400000e+04  2.040352e+07   104.000000         0.000000
# 75%    5772.250000  9.600000e+04  7.644231e+07   116.000000         0.000000
# max    7659.000000  2.400000e+06  2.847246e+09   366.000000         1.000000
#
#           rating_G  rating_NC-17  rating_Not Rated    rating_PG  rating_PG-13  \
# count  7412.000000   7412.000000       7412.000000  7412.000000   7412.000000
# mean      0.020507      0.003103          0.034808     0.164598      0.281840
# std       0.141737      0.055623          0.183307     0.370842      0.449926
# min       0.000000      0.000000          0.000000     0.000000      0.000000
# 25%       0.000000      0.000000          0.000000     0.000000      0.000000
# 50%       0.000000      0.000000          0.000000     0.000000      0.000000
# 75%       0.000000      0.000000          0.000000     0.000000      1.000000
# max       1.000000      1.000000          1.000000     1.000000      1.000000
#
#        ...  company_Zoetrope Studios  company_Zucker Brothers Productions  \
# count  ...               7412.000000                          7412.000000
# mean   ...                  0.000944                             0.000135
# std    ...                  0.030719                             0.011615
# min    ...                  0.000000                             0.000000
# 25%    ...                  0.000000                             0.000000
# 50%    ...                  0.000000                             0.000000
# 75%    ...                  0.000000                             0.000000
# max    ...                  1.000000                             1.000000
#
#        company_Zupnik-Curtis Enterprises  company_double A Films  \
# count                        7412.000000             7412.000000
# mean                            0.000135                0.000135
# std                             0.011615                0.011615
# min                             0.000000                0.000000
# 25%                             0.000000                0.000000
# 50%                             0.000000                0.000000
# 75%                             0.000000                0.000000
# max                             1.000000                1.000000
#
#        company_erbp  company_i am OTHER  company_i5 Films  \
# count   7412.000000         7412.000000       7412.000000
# mean       0.000135            0.000135          0.000135
# std        0.011615            0.011615          0.011615
# min        0.000000            0.000000          0.000000
# 25%        0.000000            0.000000          0.000000
# 50%        0.000000            0.000000          0.000000
# 75%        0.000000            0.000000          0.000000
# max        1.000000            1.000000          1.000000
#
#        company_iDeal Partners Film Fund  company_micro_scope  company_thefyzz
# count                       7412.000000          7412.000000      7412.000000
# mean                           0.000135             0.000135         0.000135
# std                            0.011615             0.011615         0.011615
# min                            0.000000             0.000000         0.000000
# 25%                            0.000000             0.000000         0.000000
# 50%                            0.000000             0.000000         0.000000
# 75%                            0.000000             0.000000         0.000000
# max                            1.000000             1.000000         1.000000
#
# [8 rows x 12196 columns]

# %%
# Check balance of target values
y.value_counts()
# Out:
# 6.6    348
# 6.4    344
# 6.2    339
# 6.5    326
# 6.7    318
#       ...
# 2.1      2
# 9.3      1
# 2.3      1
# 2.6      1
# 9.0      1
# Name: score, Length: 72, dtype: int64

# %%
# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,stratify=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fn/h597sxjn38g7_rgl7c7rgkph0000gp/T/ipykernel_3625/909730938.py in <module>
#       1 # Split into training and testing data
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,stratify=y)
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2439         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2440
# -> 2441         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2442
#    2443     return list(
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1598         """
#    1599         X, y, groups = indexable(X, y, groups)
# -> 1600         for train, test in self._iter_indices(X, y, groups):
#    1601             yield train, test
#    1602
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1939         if np.min(class_counts) < 2:
#    1940             raise ValueError(
# -> 1941                 "The least populated class in y has only 1"
#    1942                 " member, which is too few. The minimum"
#    1943                 " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.
